# %%
import pandas as pd

# %%
river = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지강.xls")
valley = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지계곡.xls")
park = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지공원.xls")
road = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지길.xls")
leisure_sports = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지레저스포츠.xls")
culture = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지문화.xls")
art_museum = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지미술관.xls")
museum = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지박물관.xls")
island = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지섬.xls") 
amusement_park = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지유원지.xls")
ruins = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지유적.xls")
natural_ecology = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지자연생태.xls")
recreational_forest = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지자연휴양림.xls")
observatory = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지전망대.xls")
star_observatory = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지천문대.xls")
exprience_village = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지체험마을.xls")
camp = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지캠핑장.xls")
theme_park = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지테마파크.xls")
waterfall = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지폭포.xls")
port = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지항구.xls")
beach = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지해변.xls")
lake = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지호수.xls")
arboretum = pd.read_excel("../data/Gangwon_trip_place_public_data/강원도관광지화목원.xls")
# Out:
# c:\Users\madda\AppData\Local\Programs\Python\Python38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\madda\AppData\Local\Programs\Python\Python38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\madda\AppData\Local\Programs\Python\Python38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\madda\AppData\Local\Programs\Python\Python38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
# ...

# %%
data = [river,park,road,leisure_sports,culture,art_museum,museum,island,amusement_park,ruins,natural_ecology,recreational_forest,observatory,star_observatory,exprience_village,camp,theme_park,waterfall,port,beach,lake,arboretum]

# %%
for i in data:
    i = i.drop(0,axis = 0, inplace = True)

# %%
Gangwon_trip_place_list = pd.concat(data,axis = 0)

# %%
Gangwon_trip_place_list
# Out:
#      분류     어권   시도 행정구역       관리번호     컨텐츠번호               카테고리     대표제목  \
# 1     강  ko_KR  강원도  횡성군   AA0002_T       1.0   HoengseongSights       섬강
# 2     강  ko_KR  강원도  화천군   AA0005_T       2.0     HwacheonSights      북한강
# 3     강  ko_KR  강원도  양구군   AA0006_T       3.0       YangguSights      소양호
# 4     강  ko_KR  강원도  양구군   AA0007_T       4.0       YangguSights      수입천
# 5     강  ko_KR  강원도  양양군   AA0009_T       5.0     YangyangSights      남대천
# ..  ...    ...  ...  ...        ...       ...                ...      ...
# 6   화목원  ko_KR  강원도  홍천군   AD0015_T    1057.0    HongcheonSights  아로마허브동산
# 7   화목원  ko_KR  강원도  홍천군   AD0014_T     525.0    HongcheonSights    허브의 집
# 8   화목원  ko_KR  강원도  양양군  AC10030_T  256858.0     YangyangSights  오색 허브농원
# 9   화목원  ko_KR  강원도  평창군   AA8002_T    1073.0  PyeongchangSights  한국자생식물원
# 10  화목원  ko_KR  강원도  평창군   AA8003_T    1074.0  PyeongchangSights     허브나라
#
#                               핵심내용                    도로명주소  ...  \
# ...

# %%
Gangwon_trip_place_list.to_csv("../data/Gangwon_trip_place_list.csv", encoding = "utf-8-sig", index = False)
